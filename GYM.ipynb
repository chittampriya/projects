# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:projects/dataset/GYM.csv")

# %%
data.head()
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221

# %%
data.tail()
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
data.describe()
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
data.shape
# Out:
# (3000, 5)

# %%
print(data.shape[0])
print(data.shape[1])
# Out:
# 3000
# 5

# %%
data.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
data.isnull()
# Out:
#       Lifter Name    Age  Weight Class  Lift Type  Amount Lifted (kg)
# 0           False  False         False      False               False
# 1           False  False         False      False               False
# 2           False  False         False      False               False
# 3           False  False         False      False               False
# 4           False  False         False      False               False
# ...           ...    ...           ...        ...                 ...
# 2995        False  False         False      False               False
# 2996        False  False         False      False               False
# 2997        False  False         False      False               False
# 2998        False  False         False      False               False
# 2999        False  False         False      False               False
#
# [3000 rows x 5 columns]

# %%
data.isnull().head()
# Out:
#    Lifter Name    Age  Weight Class  Lift Type  Amount Lifted (kg)
# 0        False  False         False      False               False
# 1        False  False         False      False               False
# 2        False  False         False      False               False
# 3        False  False         False      False               False
# 4        False  False         False      False               False

# %%
data.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Lifter Name           False
# Age                   False
# Weight Class          False
# Lift Type             False
# Amount Lifted (kg)    False
# dtype: bool

# %%
#top 5 name based amount lift

top_5=data["Amount Lifted (kg)"].sort_values(ascending=False).head()
print(top_5)
# Out:
# 2778    399
# 2758    399
# 2795    399
# 1207    399
# 2105    399
# Name: Amount Lifted (kg), dtype: int64

# %%
#count of list types with names

count_squat=data['Lift Type'].value_counts()['Squat']
print(count_squat)

count_benchpress=data['Lift Type'].value_counts()['Bench Press']
print(count_benchpress)

count_deadlift=data['Lift Type'].value_counts()['Deadlift']
print(count_deadlift)
# Out:
# 964
# 1011
# 1025

# %%
#age above 50

age_50 = data[data['Age']>50]
age_50
# Out:
#            Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1             John Doe   60        83 kg  Bench Press                 179
# 4         Laura Taylor   56        74 kg     Deadlift                 221
# 5         Sarah Thomas   56        74 kg        Squat                 264
# 8      Michael Johnson   55        93 kg        Squat                 265
# 12    Matthew Anderson   64        74 kg  Bench Press                 398
# ...                ...  ...          ...          ...                 ...
# 2989       Chris Brown   56        52 kg     Deadlift                 182
# 2991          John Doe   64        93 kg     Deadlift                 263
# 2992          John Doe   51        52 kg  Bench Press                 170
# 2994      Sarah Thomas   62       105 kg  Bench Press                 191
# 2997      Sarah Thomas   62         Open        Squat                 148
#
# [917 rows x 5 columns]

# %%
#weight class above 100

weight_100=data[data['Weight Class']>100]
weight
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #weight class above 100
# ----> 3 weight_100=data[data['Weight Class']>100]
#       4 weight
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
#deadlift candidates

deadlift = data[data['Lift Type'] =='Deadlift']
deadlift
# Out:
#        Lifter Name  Age Weight Class Lift Type  Amount Lifted (kg)
# 4     Laura Taylor   56        74 kg  Deadlift                 221
# 6      Emily Davis   40        83 kg  Deadlift                 132
# 10    Laura Taylor   31        52 kg  Deadlift                 328
# 11      Daniel Lee   38        52 kg  Deadlift                 347
# 15      Daniel Lee   37        59 kg  Deadlift                 133
# ...            ...  ...          ...       ...                 ...
# 2989   Chris Brown   56        52 kg  Deadlift                 182
# 2990  Laura Taylor   23         Open  Deadlift                 287
# 2991      John Doe   64        93 kg  Deadlift                 263
# 2996    Daniel Lee   39         Open  Deadlift                 244
# 2999    Daniel Lee   22        83 kg  Deadlift                 280
#
# [1025 rows x 5 columns]

# %%
deadlift=data['Lift Type'].value_counts('Deadlift')
deadlift
# Out:
# Lift Type
# Deadlift       0.341667
# Bench Press    0.337000
# Squat          0.321333
# Name: proportion, dtype: float64

# %%
#lineplot
sns.lineplot(x='Age',y='Lift Type',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Lift Type'>

# %%
data.head()
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221

# %%
sns.lineplot(x='Lift Type',y='Weight Class',data=data)
# Out:
# <Axes: xlabel='Lift Type', ylabel='Weight Class'>

# %%
sns.barplot(x='Age',y='Amount Lifted (kg)',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Amount Lifted (kg)'>

# %%
sns.barplot(x='Age',y='Amount Lifted (kg)',data=data)
age_50 = data[data['Age']>50]
age_50
#sns.barplot(x='age_50',y='Amount Lifted (kg)',data=data)
# Out:
#            Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1             John Doe   60        83 kg  Bench Press                 179
# 4         Laura Taylor   56        74 kg     Deadlift                 221
# 5         Sarah Thomas   56        74 kg        Squat                 264
# 8      Michael Johnson   55        93 kg        Squat                 265
# 12    Matthew Anderson   64        74 kg  Bench Press                 398
# ...                ...  ...          ...          ...                 ...
# 2989       Chris Brown   56        52 kg     Deadlift                 182
# 2991          John Doe   64        93 kg     Deadlift                 263
# 2992          John Doe   51        52 kg  Bench Press                 170
# 2994      Sarah Thomas   62       105 kg  Bench Press                 191
# 2997      Sarah Thomas   62         Open        Squat                 148
#
# [917 rows x 5 columns]

# %%
sns.countplot(x='Weight Class',data=data)
# Out:
# <Axes: xlabel='Weight Class', ylabel='count'>

# %%
sns.boxplot(x='Age',y='Amount Lifted (kg)',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Amount Lifted (kg)'>

# %%
sns.violinplot(x='Weight Class',y='Amount Lifted (kg)',data=data)
# Out:
# <Axes: xlabel='Weight Class', ylabel='Amount Lifted (kg)'>

# %%
sns.stripplot(x='Age',y='Lift Type',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Lift Type'>

# %%
sns.displot(x='Age',y='Amount Lifted (kg)',data=data)

# %%
sns.histplot(x='Weight Class',y='Age',data=data)
# Out:
# <Axes: xlabel='Weight Class', ylabel='Age'>

# %%
sns.pairplot(data,hue='Weight Class')

# %%
sns.catplot(data=data,x='Age',y='Weight Class')
