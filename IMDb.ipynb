# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("D:projects/dataset/IMDb1.csv")
data2=pd.read_csv("D:projects/dataset/IMDb2.csv")
data3=pd.read_csv("D:projects/dataset/IMDb3.csv")

# %%
data1.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
data2.head()
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
#
#            Director                                   Star Cast  MetaScore  \
# 0         Jim Hanon         Louie LeonardoChad AllenJack Guzman       45.0
# 1      Bo Widerberg  Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2  Nanette Burstein          Robert EvansEddie AlbertPeter Bart       75.0
# 3       Sean Mullin          Andy AndresRoger AngellMarty Appel       79.0
# 4       Ken Russell      Robert PowellGeorgina HaleLee Montague       66.0
#
# ...

# %%
data3.head()
# Out:
#                            Title         Director         Star Cast  Year  \
# 0        The Biggest Little Farm     John Chester      John Chester  2018
# 1         Pokémon the Movie 2000  Kunihiko Yuyama   Veronica Taylor  1999
# 2  When Hitler Stole Pink Rabbit    Caroline Link  Riva Krymalowski  2019
# 3     Return from Witch Mountain       John Hough       Bette Davis  1978
# 4                   Summer Magic    James Neilson      Hayley Mills  1963
#
#    IMDb Rating  MetaScore Certificates        Genre Second_Genre Third_Genre  \
# 0          8.0       73.0           PG  Documentary       Family      Family
# 1          6.1       28.0            G    Animation       Action   Adventure
# 2          7.0       54.0           PG    Biography        Drama      Family
# 3          5.7       51.0            G    Adventure       Family     Fantasy
# 4          6.9       57.1            G       Comedy       Family     Musical
#
# ...

# %%
data1.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %%
data2.tail()
# Out:
#                                               Title  IMDb Rating  Year  \
# 3168  The Lord of the Rings: The Return of the King          9.0  2003
# 3169                               Schindler's List          9.0  1993
# 3170                                The Dark Knight          9.0  2008
# 3171                                  The Godfather          9.2  1972
# 3172                       The Shawshank Redemption          9.3  1994
#
#      Certificates      Genre              Director  \
# 3168        PG-13     Action         Peter Jackson
# 3169            R  Biography      Steven Spielberg
# 3170        PG-13     Action     Christopher Nolan
# 3171            R      Crime  Francis Ford Coppola
# 3172            R      Drama        Frank Darabont
#
#                                           Star Cast  MetaScore  \
# 3168        J.R.R. TolkienFran WalshPhilippa Boyens       94.0
# 3169           Liam NeesonRalph FiennesBen Kingsley       95.0
# ...

# %%
data3.tail()
# Out:
#                      Title        Director       Star Cast  Year  IMDb Rating  \
# 995  The Boy and the Heron  Hayao Miyazaki    Soma Santoki  2023          7.5
# 996        Despicable Me 4    Chris Renaud    Steve Carell  2024          6.3
# 997             Inside Out     Pete Docter     Amy Poehler  2015          8.1
# 998                     IF  John Krasinski  Cailey Fleming  2024          6.5
# 999           Inside Out 2     Kelsey Mann     Amy Poehler  2024          7.9
#
#      MetaScore Certificates      Genre Second_Genre Third_Genre  \
# 995       91.0        PG-13  Animation    Adventure       Drama
# 996       50.0           PG  Animation    Adventure      Comedy
# 997       94.0           PG  Animation    Adventure      Comedy
# 998       46.0           PG  Animation       Comedy       Drama
# 999       73.0           PG  Animation    Adventure      Comedy
#
#                                             Poster-src  Duration (minutes)
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3173 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               3173 non-null   object
#  1   IMDb Rating         3173 non-null   float64
#  2   Year                3173 non-null   int64
#  3   Certificates        3173 non-null   object
#  4   Genre               3173 non-null   object
#  5   Director            3173 non-null   object
#  6   Star Cast           3173 non-null   object
#  7   MetaScore           3173 non-null   float64
#  8   Poster-src          3173 non-null   object
#  9   Duration (minutes)  3173 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 248.0+ KB

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Director            1000 non-null   object
#  2   Star Cast           1000 non-null   object
#  3   Year                1000 non-null   int64
#  4   IMDb Rating         1000 non-null   float64
#  5   MetaScore           1000 non-null   float64
#  6   Certificates        1000 non-null   object
#  7   Genre               1000 non-null   object
#  8   Second_Genre        1000 non-null   object
#  9   Third_Genre         1000 non-null   object
#  10  Poster-src          1000 non-null   object
#  11  Duration (minutes)  1000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
data1.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
data2.describe()
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  3173.000000  3173.000000  3173.000000         3173.000000
# mean      6.931012  2004.958399    65.993066          116.304822
# std       0.805202    16.819985    11.358619           22.123032
# min       3.900000  1917.000000    20.000000           46.000000
# 25%       6.400000  1997.000000    64.000000          105.000000
# 50%       6.900000  2010.000000    66.000000          116.300000
# 75%       7.500000  2017.000000    69.000000          122.000000
# max       9.500000  2025.000000   100.000000          317.000000

# %%
data3.describe()
# Out:
#               Year  IMDb Rating    MetaScore  Duration (minutes)
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean   2003.178000     6.418700    57.077100          100.034000
# std      18.697216     0.943064    15.051861           17.032938
# min    1921.000000     4.000000    11.000000           55.000000
# 25%    1995.000000     5.800000    48.000000           90.000000
# 50%    2007.500000     6.400000    57.100000           98.000000
# 75%    2017.000000     7.100000    66.000000          106.000000
# max    2024.000000     8.600000    99.000000          260.000000

# %%
data1.isnull()
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0    False        False  False         False  False     False      False
# 1    False        False  False         False  False     False      False
# 2    False        False  False         False  False     False      False
# 3    False        False  False         False  False     False      False
# 4    False        False  False         False  False     False      False
# ..     ...          ...    ...           ...    ...       ...        ...
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 0        False               False
# ...

# %%
data2.isnull()
# Out:
#       Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0     False        False  False         False  False     False      False
# 1     False        False  False         False  False     False      False
# 2     False        False  False         False  False     False      False
# 3     False        False  False         False  False     False      False
# 4     False        False  False         False  False     False      False
# ...     ...          ...    ...           ...    ...       ...        ...
# 3168  False        False  False         False  False     False      False
# 3169  False        False  False         False  False     False      False
# 3170  False        False  False         False  False     False      False
# 3171  False        False  False         False  False     False      False
# 3172  False        False  False         False  False     False      False
#
#       MetaScore  Poster-src  Duration (minutes)
# ...

# %%
data3.isnull()
# Out:
#      Title  Director  Star Cast   Year  IMDb Rating  MetaScore  Certificates  \
# 0    False     False      False  False        False      False         False
# 1    False     False      False  False        False      False         False
# 2    False     False      False  False        False      False         False
# 3    False     False      False  False        False      False         False
# 4    False     False      False  False        False      False         False
# ..     ...       ...        ...    ...          ...        ...           ...
# 995  False     False      False  False        False      False         False
# 996  False     False      False  False        False      False         False
# 997  False     False      False  False        False      False         False
# 998  False     False      False  False        False      False         False
# 999  False     False      False  False        False      False         False
#
# ...

# %%
data1.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
data3.isnull().sum()
# Out:
# Title                 0
# Director              0
# Star Cast             0
# Year                  0
# IMDb Rating           0
# MetaScore             0
# Certificates          0
# Genre                 0
# Second_Genre          0
# Third_Genre           0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
data1.isnull().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Duration (minutes)    False
# dtype: bool

# %%
data2.isnull().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Poster-src            False
# Duration (minutes)    False
# dtype: bool

# %%
data3.isnull().any()
# Out:
# Title                 False
# Director              False
# Star Cast             False
# Year                  False
# IMDb Rating           False
# MetaScore             False
# Certificates          False
# Genre                 False
# Second_Genre          False
# Third_Genre           False
# Poster-src            False
# Duration (minutes)    False
# dtype: bool

# %%
print(data1.shape)
print(data2.shape)
print(data3.shape)
# Out:
# (400, 9)
# (3173, 10)
# (1000, 12)

# %%
print(data1.shape[0])
print(data2.shape[0])
print(data3.shape[0])
# Out:
# 400
# 3173
# 1000

# %%
print(data1.shape[1])
print(data2.shape[1])
print(data3.shape[1])
# Out:
# 9
# 10
# 12

# %%
print(data1.columns)
print(data2.columns)
print(data3.columns)
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Poster-src', 'Duration (minutes)'],
#       dtype='object')
# Index(['Title', 'Director', 'Star Cast', 'Year', 'IMDb Rating', 'MetaScore',
#        'Certificates', 'Genre', 'Second_Genre', 'Third_Genre', 'Poster-src',
#        'Duration (minutes)'],
#       dtype='object')

# %%
sns.lineplot(x='IMDb Rating',y='Certificates',data=data1,color='blue')
sns.lineplot(x='IMDb Rating',y='Certificates',data=data2,color='red')
sns.lineplot(x='IMDb Rating',y='Certificates',data=data3,color='green')
# Out:
# <Axes: xlabel='IMDb Rating', ylabel='Certificates'>

# %%
sns.barplot(x='Year',y='Genre',data=data1,color='yellow')
sns.barplot(x='Year',y='Genre',data=data2,color='skyblue')
sns.barplot(x='Year',y='Genre',data=data3,color='lightgreen')
# Out:
# <Axes: xlabel='Year', ylabel='Genre'>

# %%
sns.countplot(x='Duration (minutes)',data=data1)
sns.countplot(x='Duration (minutes)',data=data2)
sns.countplot(x='Duration (minutes)',data=data3)
# Out:
# <Axes: xlabel='Duration (minutes)', ylabel='count'>

# %%
sns.boxplot(x='Duration (minutes)',y='MetaScore',data=data1)
#sns.boxplot(x='IMDb Rating',y='Year',data=data2)
#sns.boxplot(x='IMDb Rating',y='Year',data=data3)
# Out:
# <Axes: xlabel='Duration (minutes)', ylabel='MetaScore'>

# %%
sns.violinplot(x='IMDb Rating',y='Certificates',data=data1)
#sns.violinplot(x='IMDb Rating',y='Certificates',data=data2)
#sns.violinplot(x='IMDb Rating',y='Certificates',data=data3)
# Out:
# <Axes: xlabel='IMDb Rating', ylabel='Certificates'>

# %%
sns.stripplot(x='Year',y='Genre',data=data1)
#sns.stripplot(x='Year',y='Genre',data=data2)
#sns.stripplot(x='Year',y='Genre',data=data3)
# Out:
# <Axes: xlabel='Year', ylabel='Genre'>

# %%
sns.displot(x='MetaScore',data=data1)
sns.displot(x='MetaScore',data=data2)
sns.displot(x='MetaScore',data=data3)

# %%
sns.histplot(x='Duration (minutes)',data=data1)
#sns.histplot(x='Duration (minutes)',data=data2)
#sns.histplot(x='Duration (minutes)',data=data3)
# Out:
# <Axes: xlabel='Duration (minutes)', ylabel='Count'>

# %%
sns.pairplot(data=data1)
#sns.pairplot(data=data2)
#sns.pairplot(data=data3)

# %%
sns.catplot(x='Year',y='Genre',data=data1)
sns.catplot(x='Year',y='Genre',data=data2)
sns.catplot(x='Year',y='Genre',data=data3)
