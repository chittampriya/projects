# %%
# !pip install mysql-connector
# !pip install --upgrade mysql-connector-python

# %%
import mysql.connector
import pandas as pd
import seaborn as sns

# %%
db=mysql.connector.connect(
    host='localhost',
    user='root',
    password='Chittam@2003',
    database='mobiles',
    auth_plugin='mysql_native_password'

)

mycursor=db.cursor()

print(db)

# %%
mycursor.execute("Select * from details")

output=mycursor.fetchall()

for x in output:
    print(x)
# Out:
# (1, 'vivo', 'T3pro5G', 'android', 'snapdragon7gen', 6.77, 8, 128, 16, 58, 'India', 'orange', 5500, 12, 29999, 2)
# (2, 'motorola', 'edge50pro5G', 'android', 'snapdragon7gen', 6.7, 12, 256, 50, 73, 'India', 'cream', 4500, 12, 35999, 2)
# (3, 'realme', 'p1pro5G', 'android', 'snpdragon6gen', 6.7, 12, 256, 16, 58, 'India', 'blue', 5000, 12, 20999, 1)
# (4, 'realme', 'p15G', 'android', 'mediatek', 6.67, 6, 128, 16, 52, 'India', 'red', 5000, 12, 15999, 1)
# (5, 'realme', '12po5G', 'android', 'snapdragon', 6.7, 8, 128, 16, 90, 'India', 'blue', 5000, 12, 22999, 1)
# (6, 'google', 'pixel7', 'android', 'google', 6.3, 8, 128, 10, 62, 'China', 'snow', 4270, 9, 32999, 2)
# (7, 'vivo', 'v405G', 'android', 'snapdragon', 6.78, 8, 128, 50, 100, 'India', 'grey', 5500, 12, 34999, 2)
# (8, 'oppo', 'K12x5G', 'android', 'mediatek', 6.67, 4, 64, 8, 34, 'India', 'blue', 5100, 12, 12999, 0)
# (9, 'oppo', 'Reno12Pro5G', 'android', 'mediatek', 6.7, 12, 256, 50, 108, 'India', 'gold', 5000, 9, 36999, 2)
# ...

# %%
query="select * from details"

data= pd.read_sql(query,db)
# Out:
# C:\Users\veere\AppData\Local\Temp\ipykernel_24256\2807700685.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data= pd.read_sql(query,db)

# %%
data.head()
# Out:
#    id phonename    modeltype phonetype   processortype  display  ram_GB  \
# 0   1      vivo      T3pro5G   android  snapdragon7gen     6.77     8.0
# 1   2  motorola  edge50pro5G   android  snapdragon7gen     6.70    12.0
# 2   3    realme      p1pro5G   android   snpdragon6gen     6.70    12.0
# 3   4    realme         p15G   android        mediatek     6.67     6.0
# 4   5    realme       12po5G   android      snapdragon     6.70     8.0
#
#    rom_GB  frontcam_MP  backcam_MP manfcountry type_of_color  battery  \
# 0   128.0         16.0        58.0       India        orange   5500.0
# 1   256.0         50.0        73.0       India         cream   4500.0
# 2   256.0         16.0        58.0       India          blue   5000.0
# 3   128.0         16.0        52.0       India           red   5000.0
# 4   128.0         16.0        90.0       India          blue   5000.0
#
#    charger_volt     cost  segments
# 0          12.0  29999.0         2
# 1          12.0  35999.0         2
# ...

# %%
data.tail()
# Out:
#       id phonename    modeltype phonetype       processortype  display  \
# 504  505   OnePlus            9   android          Snapdragon     6.55
# 505  506      Vivo      X70 Pro   android              Exynos      NaN
# 506  507  Motorola      Edge 20   android          Snapdragon     6.70
# 507  508     Honor      50 Lite   android  MediaTek Dimensity     6.67
# 508  509    Xiaomi  Poco X3 Pro   android          Snapdragon     6.67
#
#      ram_GB  rom_GB  frontcam_MP  backcam_MP manfcountry    type_of_color  \
# 504     NaN   256.0         48.0         NaN       China      Winter Mist
# 505    12.0     NaN         50.0        12.0       China     Cosmic Black
# 506     NaN   128.0        108.0        32.0       India  Frosted Emerald
# 507     8.0     NaN        108.0         NaN       China       Ocean Blue
# 508     8.0   256.0          NaN        16.0       China    Golden Bronze
#
#      battery  charger_volt     cost  segments
# 504   4500.0          65.0  49990.0         2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             509 non-null    int64
#  1   phonename      509 non-null    object
#  2   modeltype      509 non-null    object
#  3   phonetype      509 non-null    object
#  4   processortype  509 non-null    object
#  5   display        489 non-null    float64
#  6   ram_GB         471 non-null    float64
#  7   rom_GB         480 non-null    float64
#  8   frontcam_MP    497 non-null    float64
#  9   backcam_MP     480 non-null    float64
#  10  manfcountry    507 non-null    object
#  11  type_of_color  505 non-null    object
#  12  battery        474 non-null    float64
#  13  charger_volt   470 non-null    float64
#  14  cost           503 non-null    float64
#  15  segments       509 non-null    int64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 63.8+ KB

# %%
data.describe()
# Out:
#               id     display      ram_GB     rom_GB  frontcam_MP  backcam_MP  \
# count  509.00000  489.000000  471.000000  480.00000   497.000000  480.000000
# mean   255.00000    6.375112    7.059448  139.95000    20.997988   45.660417
# std    147.07991    0.504555    6.432685   96.42528    18.952349   36.274920
# min      1.00000    4.300000    1.000000    4.00000     1.000000    4.000000
# 25%    128.00000    6.300000    4.000000   64.00000     8.000000   13.000000
# 50%    255.00000    6.500000    6.000000  128.00000    16.000000   48.000000
# 75%    382.00000    6.700000    8.000000  128.00000    32.000000   64.000000
# max    509.00000    7.600000  128.000000  512.00000   108.000000  272.000000
#
#            battery  charger_volt           cost    segments
# count   474.000000    470.000000     503.000000  509.000000
# mean   4361.835443     23.976596   40340.409543    1.589391
# std     892.974796     14.867771   31441.221930    1.082414
# ...

# %%
data.isnull().sum()
# Out:
# id                0
# phonename         0
# modeltype         0
# phonetype         0
# processortype     0
# display          20
# ram_GB           38
# rom_GB           29
# frontcam_MP      12
# backcam_MP       29
# manfcountry       2
# type_of_color     4
# battery          35
# charger_volt     39
# cost              6
# segments          0
# dtype: int64

# %%
data['rom_GB']=data['rom_GB'].fillna(data['rom_GB'].mean)

# %%
data['frontcam_MP']=data['frontcam_MP'].fillna(data['frontcam_MP'].mean)

# %%
data['battery']=data['battery'].fillna(data['battery'].mean)

# %%
data['phonename']=data['phonename'].fillna(data['phonename'].mean)

# %%
data['phonetype']=data['phonetype'].fillna(data['phonetype'].mean)

# %%
data['processortype']=data['processortype'].fillna(data['processortype'].mean)

# %%
data['display']=data['display'].fillna(data['display'].mean)

# %%
data['ram_GB']=data['ram_GB'].fillna(data['ram_GB'].mean)

# %%
data['backcam_MP']=data['backcam_MP'].fillna(data['backcam_MP'].mean)

# %%
data['type_of_color']=data['type_of_color'].fillna(data['type_of_color'].mean)

# %%
data['charger_volt']=data['charger_volt'].fillna(data['charger_volt'].mean)

# %%
data['cost']=data['cost'].fillna(data['cost'].mean)

# %%
data['manfcountry']=data['manfcountry'].fillna(data['manfcountry'].mean)

# %%
data.isnull().sum()
# Out:
# id               0
# phonename        0
# modeltype        0
# phonetype        0
# processortype    0
# display          0
# ram_GB           0
# rom_GB           0
# frontcam_MP      0
# backcam_MP       0
# manfcountry      0
# type_of_color    0
# battery          0
# charger_volt     0
# cost             0
# segments         0
# dtype: int64

# %%
sns.lineplot(y='phonename',x='manfcountry',data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sns.lineplot(y='phonename',x='manfcountry',data=data)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:508, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     505 if not p.has_xy_data:
#     506     return ax
# --> 508 p._attach(ax)
#     510 # Other functions have color as an explicit param,
#     511 # and we should probably do that here too
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:1135, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1133                 order = None
# ...
